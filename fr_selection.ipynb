# %% [markdown]
# # AED : Sélection d'Échantillon
#
# Dans ce notebook, nous allons voir commment sélectionner un échantillon en utilisant le jeu de données COQ.
#
# Pour ce faire, nous allons importer directement l'ensemble complet de données depuis une URL.

# %%
# Importations de base.
import pandas as pd
import plotly.express as px

# %%
# Importer l'ensemble de données depuis une url.
url = "https://www.qogdata.pol.gu.se/data/qog_ei_ts_sept21.xlsx"
df = pd.read_excel(url)
df.head()
# Out:
#          cname  ccode  year    cname_qog  ccode_qog ccodealp ccodealp_year  \
# 0  Afghanistan    4.0  1946  Afghanistan          4      AFG         AFG46
# 1  Afghanistan    4.0  1947  Afghanistan          4      AFG         AFG47
# 2  Afghanistan    4.0  1948  Afghanistan          4      AFG         AFG48
# 3  Afghanistan    4.0  1949  Afghanistan          4      AFG         AFG49
# 4  Afghanistan    4.0  1950  Afghanistan          4      AFG         AFG50
#
#    ccodecow  ccodevdem        cname_year  ... wdi_precip  wdi_tpa  wvs_ameop  \
# 0     700.0       36.0  Afghanistan 1946  ...        NaN      NaN        NaN
# 1     700.0       36.0  Afghanistan 1947  ...        NaN      NaN        NaN
# 2     700.0       36.0  Afghanistan 1948  ...        NaN      NaN        NaN
# 3     700.0       36.0  Afghanistan 1949  ...        NaN      NaN        NaN
# 4     700.0       36.0  Afghanistan 1950  ...        NaN      NaN        NaN
#
#    wvs_ceom  wvs_deop  wvs_epmip  wvs_epmpp  wvs_imeop  wvs_pedp  wvs_ploem
# 0       NaN       NaN        NaN        NaN        NaN       NaN        NaN
# 1       NaN       NaN        NaN        NaN        NaN       NaN        NaN
# 2       NaN       NaN        NaN        NaN        NaN       NaN        NaN
# 3       NaN       NaN        NaN        NaN        NaN       NaN        NaN
# 4       NaN       NaN        NaN        NaN        NaN       NaN        NaN
#
# [5 rows x 414 columns]

# %%
# Sélectionner un sous-ensemble de variables.
# Remarque: ici, j'ai supprimé l'ensemble complet de données car je suis sûr que je ne vais plus l'utiliser dans ce notebook.
# Mais cela est dangereux et en cas de doute, évitez-cela. Pour ce faire, donnez un nouveau nom à ce sous-ensemble de df, p.ex. df_sample.
df = df[['cname', 'ccodealp', 'year', 'oecd_eps', 'cckp_temp', 'cckp_rain']]
df.describe(include="all")
# Out:
#               cname ccodealp          year    oecd_eps     cckp_temp  \
# count         11722    11722  11722.000000  799.000000  11135.000000
# unique          204      202           NaN         NaN           NaN
# top     Afghanistan      AFG           NaN         NaN           NaN
# freq             75       75           NaN         NaN           NaN
# mean            NaN      NaN   1988.188193    1.567856     19.009990
# std             NaN      NaN     20.252364    0.960634      8.123073
# min             NaN      NaN   1946.000000    0.208333     -9.216667
# 25%             NaN      NaN   1972.000000    0.687500     11.691667
# 50%             NaN      NaN   1990.000000    1.354167     22.416667
# 75%             NaN      NaN   2005.000000    2.262500     25.466667
# max             NaN      NaN   2020.000000    4.133333     29.366667
#
#            cckp_rain
# count   11135.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean      100.390635
# std        71.011072
# min         1.166667
# 25%        46.045833
# 50%        86.850000
# 75%       144.287500
# max       417.391667

# %% [markdown]
# Nous pouvons voir qu'il y a des valeurs manquantes. Le nombre de valeurs (`count`) n'est pas le même pour toutes les colonnes.

# %%
# Afficher le nombre d'observations par année où la variable 'oecd_eps' n'est pas nulle (NaN).
df[pd.notnull(df['oecd_eps'])].groupby(['year']).size().reset_index(name='counts')
# Voici une explication de la commande:
# 1. df[pd.notnull(df['oecd_eps'])] : Sélectionne les lignes où 'oecd_eps' n'est pas nulle.
# 2. .groupby(['year']) : Regroupe le DataFrame par la colonne année.
# 3. .size() : Calcule la taille de chaque groupe (nombre de lignes).
# 4. .reset_index(name='counts'): Réinitialise l'index pour inclure le nombre de valeurs en tant que nouvelle colonne nommée 'counts'.
# Out:
#     year  counts
# 0   1990      28
# 1   1991      28
# 2   1992      29
# 3   1993      32
# 4   1994      32
# 5   1995      33
# 6   1996      33
# 7   1997      33
# 8   1998      33
# 9   1999      33
# 10  2000      33
# 11  2001      33
# 12  2002      33
# 13  2003      33
# 14  2004      33
# 15  2005      33
# 16  2006      33
# 17  2007      33
# 18  2008      34
# 19  2009      34
# 20  2010      34
# 21  2011      34
# 22  2012      34
# 23  2013      17
# 24  2014      17
# 25  2015      17

# %% [markdown]
# Sur la base des tableaux précédents, je vais me limiter aux pays pour lesquels il y a des données pour le résultat (`oecd_eps`) et aux années de 1993 à 2012, afin d'avoir une taille d'échantillon relativement constante.

# %%
# Sélection du sous-échantillon.
df_s = df[pd.notnull(df['oecd_eps']) & (df['year'] >= 1993) & (df['year'] <= 2012)]
df_s.describe()
# Out:
#               year    oecd_eps   cckp_temp   cckp_rain
# count   663.000000  663.000000  663.000000  663.000000
# mean   2002.583710    1.606863   10.686664   76.825842
# std       5.773822    0.940719    7.445290   41.994952
# min    1993.000000    0.333333   -7.433333   28.183333
# 25%    1998.000000    0.750000    7.458333   49.870833
# 50%    2003.000000    1.479167   10.141667   63.166667
# 75%    2008.000000    2.333333   13.729167   92.204167
# max    2012.000000    4.133333   26.375000  281.100000

# %%
# Afficher le nombre d'observations par année où la variable 'oecd_eps' n'est pas nulle.
df_s[pd.notnull(df['oecd_eps'])].groupby(['year']).size().reset_index(name='counts')
# Out:
# <ipython-input-13-5aebb894354e>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_s[pd.notnull(df['oecd_eps'])].groupby(['year']).size().reset_index(name='counts')
#     year  counts
# 0   1993      32
# 1   1994      32
# 2   1995      33
# 3   1996      33
# 4   1997      33
# 5   1998      33
# 6   1999      33
# 7   2000      33
# 8   2001      33
# 9   2002      33
# 10  2003      33
# 11  2004      33
# 12  2005      33
# 13  2006      33
# 14  2007      33
# 15  2008      34
# 16  2009      34
# 17  2010      34
# 18  2011      34
# 19  2012      34

# %%
# Pour connaître la couverture pour chaque pays dans 'df_s'.
df_s.groupby(['cname']).size().reset_index(name='counts')
# Out:
#                                                 cname  counts
# 0                                           Australia      20
# 1                                             Austria      20
# 2                                             Belgium      20
# 3                                              Brazil      18
# 4                                              Canada      20
# 5                                               China      20
# 6                                      Czech Republic      20
# 7                                             Denmark      20
# 8                                             Finland      20
# 9                                              France      20
# 10                                            Germany      20
# 11                                             Greece      20
# 12                                            Hungary      20
# 13                                              India      20
# 14                                          Indonesia      20
# 15                                            Ireland      20
# 16                                              Italy      20
# 17                                              Japan      20
# 18                                             Mexico      20
# 19                                        Netherlands      20
# 20                                             Norway      20
# 21                                             Poland      20
# 22                                           Portugal      20
# 23                                  Republic of Korea      20
# 24                                             Russia      20
# 25                                           Slovakia      20
# 26                                           Slovenia       5
# 27                                       South Africa      20
# 28                                              Spain      20
# 29                                             Sweden      20
# 30                                        Switzerland      20
# 31                                             Turkey      20
# 32  United Kingdom of Great Britain and Northern I...      20
# 33                           United States of America      20

# %% [markdown]
# Ici, vous pouvez décider. Préférez-vous garder le Brésil et commencer en 1995 ou exclure le Brésil et commencer en 1993 ?
# Je suggère de commencer en 1995.

# %%
# Supprimer la Slovénie et les années avant 1995.
df_s = df_s[(df_s['cname']!="Slovenia") & (df_s['year']>=1995)]

# Vérification finale:
df_s.groupby(['cname']).size().reset_index(name='counts')
# Out:
#                                                 cname  counts
# 0                                           Australia      18
# 1                                             Austria      18
# 2                                             Belgium      18
# 3                                              Brazil      18
# 4                                              Canada      18
# 5                                               China      18
# 6                                      Czech Republic      18
# 7                                             Denmark      18
# 8                                             Finland      18
# 9                                              France      18
# 10                                            Germany      18
# 11                                             Greece      18
# 12                                            Hungary      18
# 13                                              India      18
# 14                                          Indonesia      18
# 15                                            Ireland      18
# 16                                              Italy      18
# 17                                              Japan      18
# 18                                             Mexico      18
# 19                                        Netherlands      18
# 20                                             Norway      18
# 21                                             Poland      18
# 22                                           Portugal      18
# 23                                  Republic of Korea      18
# 24                                             Russia      18
# 25                                           Slovakia      18
# 26                                       South Africa      18
# 27                                              Spain      18
# 28                                             Sweden      18
# 29                                        Switzerland      18
# 30                                             Turkey      18
# 31  United Kingdom of Great Britain and Northern I...      18
# 32                           United States of America      18

# %%
# Pour visualiser la couverture géographique sur une carte.
df_num_obs = df_s.groupby(['ccodealp']).size().reset_index(name='counts')
fig = px.choropleth(df_num_obs, locations='ccodealp',
                    locationmode='ISO-3',
                    color='counts',
                    hover_name='ccodealp',
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="aec721b1-f5d9-42fa-b9e8-91f097b73f9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aec721b1-f5d9-42fa-b9e8-91f097b73f9d")) {                    Plotly.newPlot(                        "aec721b1-f5d9-42fa-b9e8-91f097b73f9d",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eccodealp=%{location}\u003cbr\u003ecounts=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["AUS","AUT","BEL","BRA","CAN","CHE","CHN","CZE","DEU","DNK","ESP","FIN","FRA","GBR","GRC","HUN","IDN","IND","IRL","ITA","JPN","KOR","MEX","NLD","NOR","POL","PRT","RUS","SVK","SWE","TUR","USA","ZAF"],"locationmode":"ISO-3","locations":["AUS","AUT","BEL","BRA","CAN","CHE","CHN","CZE","DEU","DNK","ESP","FIN","FRA","GBR","GRC","HUN","IDN","IND","IRL","ITA","JPN","KOR","MEX","NLD","NOR","POL","PRT","RUS","SVK","SWE","TUR","USA","ZAF"],"name":"","z":[18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords", ...
